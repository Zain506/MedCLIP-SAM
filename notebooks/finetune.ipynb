# %% [markdown]
# <a href="https://colab.research.google.com/github/Zain506/MedCLIP-SAM/blob/main/notebooks/medclipsam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Fine-Tune BiomedCLIP

# %% [markdown]
# ## Import Data

# %%
from datasets import load_dataset

ds = load_dataset("adishourya/MEDPIX-ClinQA") # Import MedPIX dataset

# %%
train_valid = ds["train"].train_test_split(test_size=0.15) # Manually split: Dataset has not been pre-split into training and testing yet
training = train_valid["train"] # .select(range(1024))
validation = train_valid["test"]
print(training)

# %% [markdown]
# ## Import libraries

# %%
# %pip install open-clip-torch -q

import torch.nn.functional as F
import torch
from torch.utils.data import DataLoader
from tqdm.notebook import tqdm
import open_clip
from typing import Tuple

# %% [markdown]
# ## Class

# %%
class BiomedCLIP:
  """Define the hyperparameters temperature, beta1 and beta2, as well as the number of epochs"""
  def __init__(self, temperature: float, b1: float, b2: float, epochs=5):


    self.device: str  = "cuda" if torch.cuda.is_available() else "cpu"

    model, _, self.preprocess = open_clip.create_model_and_transforms('ViT-B-32', pretrained='laion2b_s34b_b79k')

    self.model = model.to("cuda" if torch.cuda.is_available() else "cpu")
    self.tokenizer = open_clip.get_tokenizer('ViT-B-32')
    self.t: float = temperature
    self.b1: float = b1
    self.b2: float = b2
    self.epochs: int = epochs
    self.bsize: int = 64 # batch size hard-coded (as stated in research paper to 64)


######################################### MAIN METHOD ###############################################################
  def train(self):
    optimizer = torch.optim.AdamW( # Freezing a part of the model requires us to set requires_grad=False
        self.model.parameters(), # All trainable params
        lr = 5e-6,
        weight_decay = 0.01 # L1 reg
    )
    collate_fn = self._collate_fn
    train_loader = self._loadData(collate_fn)
    # Train
    for epoch in range(self.epochs):
      for images, texts in tqdm(train_loader, desc=f"Training Epoch {epoch + 1}"):
        I_vec, T = self._prepData(images, texts) # noqa: N806
        sim = I_vec @ T.T
        sim /= self.t
        loss = self._calcLossComp(sim, self.b1) + self._calcLossComp(sim.T, self.b2)
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()
    # Save the model
    self.save_model("/content/drive/MyDrive/colab/MedCLIP-SAM/biomedclip_weights.pth")
######################################### CONSTRUCTORS ############################################################
  def _loadData(self, collation): # Create batches
    train_loader: torch.utils.data.DataLoader = DataLoader(
      training,
      batch_size=self.bsize,
      shuffle=True,
      collate_fn=collation,
      pin_memory=True,
      num_workers=0
      )
    return train_loader


  def _collate_fn(self, batch): # Convert datapoint into tensors
  # Requires data cleaning (in research paper)
    images = torch.stack([self.preprocess(x['image_id']) for x in batch])
    texts = self.tokenizer([f"Prompt: {x['question']} \nAnswer: {x['answer']}" for x in batch])
    return images, texts


  def _prepData(self, images: torch.Tensor, texts: torch.Tensor) -> Tuple[torch.Tensor, torch.Tensor]: # Encode data
    images = images.to(self.device)
    texts = texts.to(self.device)
    I_vec = self.model.encode_image(images) # noqa: N806
    I_vec = F.normalize(I_vec, p=2, dim=-1) # noqa: N806
    T = self.model.encode_text(texts)
    T = F.normalize(T, p=2, dim=-1)
    return I_vec, T


  def _calcLossComp(self, sim: torch.Tensor, b: float) -> torch.Tensor: # Loss Component Function
    A = torch.exp(sim)
    X = b*sim
    X.diagonal().fill_(-torch.inf)
    W = (self.bsize-1)*torch.softmax(X, dim=-1)
    W.diagonal().fill_(-1)
    loss = torch.sum(torch.log(torch.sum(A*W, dim=-1)))
    return loss

  def save_model(self, path) -> None: # Save model state dictionary
    torch.save(self.model.state_dict(), path)

# %% [markdown]
# # Train: Obtain new weights post fine-tuning

# %%
from google.colab import drive
drive.mount('/content/drive/')

# %%
clip = BiomedCLIP(0.5, 5, 5)
clip.train()
